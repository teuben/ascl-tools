# %%
import requests
import json
import re
import numpy as np
import pandas as pd
import github_config  # a hidden file in the directory with github API username and password info

#create a blank API query that returns every code
response = requests.get("https://dev.ascl.net/api/search/?q=\"\"&fl=bibcode,site_list")
j = response.json()

#now, see if the values in the 'site_list' field are valid github repos
validRepo = "^.*\"(https://github.com/.*/.*\").*$"
repos = np.array([])
for code in j:
    gitRepos = re.match(validRepo, code['site_list'])
    if gitRepos:
        #if it contains a valid github repo, then add relevant information to the array  
        repo = gitRepos.group(1)
        url = repo.split("\"", 1)[0] + '/'
        urlRegex = "^https:\/\/github.com\/(.+?)\/(.+?)(?:\/.*)$"
        match = re.match(urlRegex, url)
        if match:
            author = match.group(1)
            repo_title = match.group(2)
            ascl_id = code['ascl_id']
            arr = np.array([author, repo_title, ascl_id])
            repos = np.append(repos, [arr])

#now we have an array of arrays with the repo name, author, and an ascl_id
data = np.reshape(repos, [-1,3])
df = pd.DataFrame({'Author': data[:,0], 'Repo': data[:,1], 'ascl_id': data[:,2]})

#get rid of duplicates
df.drop_duplicates(subset ="Repo", 
                     keep = 'first', inplace = True) 

#might need to get rid of 0000.000 ascl_ids

display(df)
# Out:
#                    Author                                               Repo  \
# 0          EdoardoCarlesi                                            cmbeasy
# 1                daddeptr                                           Needlets
# 2             piernik-dev                                            piernik
# 3                skendrew                                  midIR_sensitivity
# 4                Starlink                                           starlink
# 5     PrincetonUniversity                                    Athena-Cversion
# 6             evanoconnor                                               GR1D
# 7                mariogrs                                          Simfast21
# 8            eggplantbren                                             DNest4
# 9                  jobovy                              extreme-deconvolution
# 10                 fwhigh                           stellar-locus-regression
# 11              cconroy20                                               fsps
# 12            amrex-astro                                            MAESTRO
# 13                 teuben                                               nemo
# 14               gbrammer                                        eazy-photoz
# 15         auckland-cosmo                                          interp-mc
# 16                low-sky                                             cprops
# 17         andreimesinger                                           21cmFAST
# 18                bwoshea                                          ZEUS-MP_2
# 19                 galtay                                             sphray
# 21                 kd0kfo                                          cosmology
# 22            AMReX-Astro                                             Castro
# 23             cosmicrays                                             DRAGON
# 24                 zgazak                                                TAP
# 25              sjforeman                                         StringFast
# 26         auckland-cosmo                                        defrost-mpi
# 27                 sherpa                                             sherpa
# 28                lime-rt                                               lime
# 29             ahwkuepper                                           mcluster
# 30            rainwoodman                                             gaepsi
# ...                   ...                                                ...
# 1096  williamjameshandley                                            fgivenx
# 1097             mtazzari                                             uvplot
# 1098        duetosymmetry                                                qnm
# 1099        luizfelippesr                                         magnetizer
# 1100              atomneb                                        AtomNeb-idl
# 1101               hippke                                                tls
# 1102              fdebras                                           ECLIPS3D
# 1103               hippke                                             pulses
# 1104             HITS-AIN                                               PINK
# 1105            fcastagna                                          preprofit
# 1106           jmackereth                        monoage-velocity-dispersion
# 1107              bmoster                                             emerge
# 1108                  dfm                                          exoplanet
# 1109           phillippro                                               pexo
# 1110            rfeldmann                                              leopy
# 1111              fpavogt                                           E0102-VR
# 1112            knaidoo29                                            mistree
# 1113              Samreay                                      ChainConsumer
# 1114               cmbant                                            getdist
# 1115        CobayaSampler                                             cobaya
# 1116              AOtools                                            aotools
# 1117          astroboylrx                                               PLAN
# 1118             gmbrandt                                           xwavecal
# 1119          soleneulmer                                                bem
# 1120               shbhuk                                              mrexo
# 1121              Bo-Ning  Predicting-exoplanet-mass-and-radius-relationship
# 1123             rodluger                                        Limbdark.jl
# 1124             rodluger                                       planetplanet
# 1125              mihanke                                              athos
# 1126               pypeit                                             PypeIt
#
#        ascl_id
# 0     1007.004
# 1     1010.004
# 2     1010.005
# 3     1010.008
# 4     1407.002
# 5     1010.014
# 6     1010.022
# 7     1010.025
# 8     1010.029
# 9     1010.032
# 10    1010.035
# 11    1010.043
# 12    1010.044
# 13    1010.051
# 14    1010.052
# 15    1101.004
# 16    1102.012
# 17    1102.023
# 18    1102.028
# 19    1103.009
# 21    1712.008
# 22    1105.010
# 23    1106.011
# 24    1106.014
# 25    1106.021
# 26    1106.022
# 27    1107.005
# 28    1107.012
# 29    1107.015
# 30    1108.005
# ...        ...
# 1096  1909.014
# 1097  1911.002
# 1098  1910.022
# 1099  0000.000
# 1100  0000.000
# 1101  1910.007
# 1102  1910.008
# 1103  0000.000
# 1104  1910.001
# 1105  1910.002
# 1106  0000.000
# 1107  1910.006
# 1108  1910.005
# 1109  1910.010
# 1110  1910.011
# 1111  1910.013
# 1112  1910.016
# 1113  1910.017
# 1114  1910.018
# 1115  1910.019
# 1116  1910.021
# 1117  1911.001
# 1118  0000.000
# 1119  0000.000
# 1120  0000.000
# 1121  0000.000
# 1123  0000.000
# 1124  0000.000
# 1125  0000.000
# 1126  1911.004
#
# [1058 rows x 3 columns]

# %%
#now, we can redo statistics on the data
#first, re-obtain the language data

session = requests.Session()
session.auth = (github_config.username, github_config.password)
http_base = 'https://api.github.com/repos/'

new_arr = []


for index, row in df.iterrows():
    try:
        date = session.get(http_base+row['Author']+'/'+row['Repo']).json()['created_at']
    except:
        date = None
    r = session.get(http_base+row['Author']+'/'+row['Repo']+'/languages')
    languages = r.json()
    for key in languages:
        arr = [row['Author'], row['Repo'], row['ascl_id'], date, key, languages[key]]
        new_arr.append(arr)
        
df = pd.DataFrame(new_arr, columns=['Author', 'Repo', 'ascl-id', 'repo_date', 'Language', 'Bytes'])
display(df)
# Out:
#               Author                                               Repo  \
# 0     EdoardoCarlesi                                            cmbeasy
# 1     EdoardoCarlesi                                            cmbeasy
# 2     EdoardoCarlesi                                            cmbeasy
# 3           daddeptr                                           Needlets
# 4           daddeptr                                           Needlets
# 5           daddeptr                                           Needlets
# 6        piernik-dev                                            piernik
# 7        piernik-dev                                            piernik
# 8        piernik-dev                                            piernik
# 9        piernik-dev                                            piernik
# 10       piernik-dev                                            piernik
# 11       piernik-dev                                            piernik
# 12       piernik-dev                                            piernik
# 13       piernik-dev                                            piernik
# 14          Starlink                                           starlink
# 15          Starlink                                           starlink
# 16          Starlink                                           starlink
# 17          Starlink                                           starlink
# 18          Starlink                                           starlink
# 19          Starlink                                           starlink
# 20          Starlink                                           starlink
# 21          Starlink                                           starlink
# 22          Starlink                                           starlink
# 23          Starlink                                           starlink
# 24          Starlink                                           starlink
# 25          Starlink                                           starlink
# 26          Starlink                                           starlink
# 27          Starlink                                           starlink
# 28          Starlink                                           starlink
# 29          Starlink                                           starlink
# ...              ...                                                ...
# 3399   CobayaSampler                                             cobaya
# 3400         AOtools                                            aotools
# 3401     astroboylrx                                               PLAN
# 3402     astroboylrx                                               PLAN
# 3403     astroboylrx                                               PLAN
# 3404        gmbrandt                                           xwavecal
# 3405     soleneulmer                                                bem
# 3406          shbhuk                                              mrexo
# 3407         Bo-Ning  Predicting-exoplanet-mass-and-radius-relationship
# 3408        rodluger                                        Limbdark.jl
# 3409        rodluger                                        Limbdark.jl
# 3410        rodluger                                        Limbdark.jl
# 3411        rodluger                                        Limbdark.jl
# 3412        rodluger                                        Limbdark.jl
# 3413        rodluger                                        Limbdark.jl
# 3414        rodluger                                        Limbdark.jl
# 3415        rodluger                                        Limbdark.jl
# 3416        rodluger                                        Limbdark.jl
# 3417        rodluger                                        Limbdark.jl
# 3418        rodluger                                       planetplanet
# 3419        rodluger                                       planetplanet
# 3420        rodluger                                       planetplanet
# 3421        rodluger                                       planetplanet
# 3422         mihanke                                              athos
# 3423          pypeit                                             PypeIt
# 3424          pypeit                                             PypeIt
# 3425          pypeit                                             PypeIt
# 3426          pypeit                                             PypeIt
# 3427          pypeit                                             PypeIt
# 3428          pypeit                                             PypeIt
#
#        ascl-id             repo_date          Language     Bytes
# 0     1007.004  2013-04-13T10:55:00Z               C++   2313919
# 1     1007.004  2013-04-13T10:55:00Z                 C     20287
# 2     1007.004  2013-04-13T10:55:00Z       Objective-C      4294
# 3     1010.004  2014-02-24T18:28:03Z           Fortran     63589
# 4     1010.004  2014-02-24T18:28:03Z               IDL      7343
# 5     1010.004  2014-02-24T18:28:03Z              Perl      1782
# 6     1010.005  2013-06-14T11:31:14Z           Fortran   2863809
# 7     1010.005  2013-06-14T11:31:14Z            Python    120477
# 8     1010.005  2013-06-14T11:31:14Z             Shell     24446
# 9     1010.005  2013-06-14T11:31:14Z              Roff      7201
# 10    1010.005  2013-06-14T11:31:14Z           Gnuplot      5025
# 11    1010.005  2013-06-14T11:31:14Z          Makefile      4482
# 12    1010.005  2013-06-14T11:31:14Z                 C      3171
# 13    1010.005  2013-06-14T11:31:14Z              Perl      1060
# 14    1407.002  2012-07-24T18:15:25Z           Fortran  98837524
# 15    1407.002  2012-07-24T18:15:25Z               TeX  28588713
# 16    1407.002  2012-07-24T18:15:25Z                 C  27631397
